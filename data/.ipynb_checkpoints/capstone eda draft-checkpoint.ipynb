# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
#read the demographics dataframe

demographics = pd.read_csv('./demographics.csv')
demographics
# Out:
#      items  Date   No. Learners' ID  \
# 0      NaN  2023  3138   LN20233138
# 1      NaN  2023  3134   LN20233134
# 2      NaN  2023  3132   LN20233132
# 3      NaN  2023  3144   LN20233144
# 4      NaN  2023  3137   LN20233137
# ..     ...   ...   ...          ...
# 807    NaN  2023  3643   LN20233643
# 808    NaN  2023  3644   LN20233644
# 809    NaN  2023  3645   LN20233645
# 810    NaN  2023  3646   LN20233646
# 811    NaN  2023  3647   LN20233647
#
#                                         Full Name  Preferred Name  \
# 0                              Az Khaizuran Azman             NaN
# 1                      Deilan Raj Victor Jonathan             NaN
# 2                       Emir Aizat Bin Abd Rashid             NaN
# 3                 Hasanatul Aliah Binti Saifullah             NaN
# 4           Mohamad Syahafizin Bin Mohamad Azahar             NaN
# ..                                            ...             ...
# 807                                     Shaan Gom             NaN
# 808                                Tan Hong Liang             NaN
# 809                               Teck Waye Diong             NaN
# 810  Ungku Nur Aqilah Hidayah Binti Ungku A Halim             NaN
# 811                 Wan Adri Syafi Bin Wan Mahadi             NaN
#
#                  IC Year    Age  Gender  ...   Course ID (1)     Status  \
# 0    971021-21-6725   27  26-35    Male  ...  EC-CCST-23-001  Graduated
# 1    990709-09-5289   25  18-25    Male  ...  EC-CCST-23-001  Graduated
# 2    950818-18-6401   29  26-35    Male  ...  EC-CCST-23-001  Graduated
# 3    990922-22-5374   25  18-25  Female  ...  EC-CCST-23-001  Graduated
# 4    960903-03-5111   28  26-35    Male  ...  EC-CCST-23-001  Graduated
# ..              ...  ...    ...     ...  ...             ...        ...
# 807  980521-21-5359   26  26-35    Male  ...  WC-CITM-23-002  Graduated
# 808  980317-17-6593   26  26-35    Male  ...  WC-CITM-23-002  Graduated
# 809  971005-05-5285   27  26-35    Male  ...  WC-CITM-23-002  Graduated
# 810  991021-21-5806   25  18-25  Female  ...  WC-CITM-23-002  Graduated
# 811  991114-14-5077   25  18-25    Male  ...  WC-CITM-23-002   Drop Out
#
#     Course ID (2) Status.1  Course ID (3)  Status.2 Course ID (4)  Status.3  \
# 0             NaN      NaN            NaN       NaN           NaN       NaN
# 1             NaN      NaN            NaN       NaN           NaN       NaN
# 2             NaN      NaN            NaN       NaN           NaN       NaN
# 3             NaN      NaN            NaN       NaN           NaN       NaN
# 4             NaN      NaN            NaN       NaN           NaN       NaN
# ..            ...      ...            ...       ...           ...       ...
# 807           NaN      NaN            NaN       NaN           NaN       NaN
# 808           NaN      NaN            NaN       NaN           NaN       NaN
# 809           NaN      NaN            NaN       NaN           NaN       NaN
# 810           NaN      NaN            NaN       NaN           NaN       NaN
# 811           NaN      NaN            NaN       NaN           NaN       NaN
#
#      Course ID (5)  Status.4
# 0              NaN       NaN
# 1              NaN       NaN
# 2              NaN       NaN
# 3              NaN       NaN
# 4              NaN       NaN
# ..             ...       ...
# 807            NaN       NaN
# 808            NaN       NaN
# 809            NaN       NaN
# 810            NaN       NaN
# 811            NaN       NaN
#
# [812 rows x 64 columns]

# %%
outcome = pd.read_csv('./outcome.csv')
outcome
# Out:
#                                         Full Name  \
# 0                              Az Khaizuran Azman
# 1                      Deilan Raj Victor Jonathan
# 2                       Emir Aizat Bin Abd Rashid
# 3                 Hasanatul Aliah Binti Saifullah
# 4           Mohamad Syahafizin Bin Mohamad Azahar
# ..                                            ...
# 807                                     Shaan Gom
# 808                                Tan Hong Liang
# 809                               Teck Waye Diong
# 810  Ungku Nur Aqilah Hidayah Binti Ungku A Halim
# 811                 Wan Adri Syafi Bin Wan Mahadi
#
#                                  Email      Course ID  Attendance rate  \
# 0                azkhaizuran@gmail.com  EC-CCST-23-001            100%
# 1              deilanraj9799@gmail.com  EC-CCST-23-001            100%
# 2                  emiraizat@gmail.com  EC-CCST-23-001             93%
# 3    hasanatulaliahsaifullah@gmail.com  EC-CCST-23-001            100%
# 4               fizin.azahar@gmail.com  EC-CCST-23-001            100%
# ..                                 ...             ...             ...
# 807                 shaangom@gmail.com  WC-CITM-23-002            100%
# 808               costein.hl@gmail.com  WC-CITM-23-002             93%
# 809            diongteckwaye@gmail.com  WC-CITM-23-002            100%
# 810            ungkuaqilah99@gmail.com  WC-CITM-23-002            100%
# 811             wanadrisyafi@gmail.com  WC-CITM-23-002              0%
#
#     Final project score (Fail/ Pass/ scores)  Placement Status
# 0                                  Completed                NaN
# 1                                  Completed          Permanent
# 2                                  Completed          Permanent
# 3                                  Completed          Permanent
# 4                                  Completed                NaN
# ..                                       ...                ...
# 807                                Completed           Contract
# 808                                Completed          Permanent
# 809                                Completed          Permanent
# 810                                Completed          Permanent
# 811                                      NaN  Withdraw - Others
#
# [812 rows x 6 columns]

# %%
survey = pd.read_csv('./survey.csv')
survey
# Out:
#                                         Full Name  \
# 0                              Az Khaizuran Azman
# 1                      Deilan Raj Victor Jonathan
# 2                       Emir Aizat Bin Abd Rashid
# 3                 Hasanatul Aliah Binti Saifullah
# 4           Mohamad Syahafizin Bin Mohamad Azahar
# ..                                            ...
# 807                                     Shaan Gom
# 808                                Tan Hong Liang
# 809                               Teck Waye Diong
# 810  Ungku Nur Aqilah Hidayah Binti Ungku A Halim
# 811                 Wan Adri Syafi Bin Wan Mahadi
#
#                                  Email      Course ID    NPS  \
# 0                azkhaizuran@gmail.com  EC-CCST-23-001   8.0
# 1              deilanraj9799@gmail.com  EC-CCST-23-001   8.0
# 2                  emiraizat@gmail.com  EC-CCST-23-001   5.0
# 3    hasanatulaliahsaifullah@gmail.com  EC-CCST-23-001   8.0
# 4               fizin.azahar@gmail.com  EC-CCST-23-001   7.0
# ..                                 ...             ...   ...
# 807                 shaangom@gmail.com  WC-CITM-23-002   6.0
# 808               costein.hl@gmail.com  WC-CITM-23-002  10.0
# 809            diongteckwaye@gmail.com  WC-CITM-23-002   8.0
# 810            ungkuaqilah99@gmail.com  WC-CITM-23-002  10.0
# 811             wanadrisyafi@gmail.com  WC-CITM-23-002   NaN
#
#      Satisfaction scores  value-time-spent  Content  Instructor  Experience
# 0                    4.0               4.0      4.0         5.0         4.0
# 1                    4.0               5.0      4.7         3.8         2.5
# 2                    3.0               3.0      2.7         3.3         3.5
# 3                    4.0               5.0      4.7         4.5         5.0
# 4                    3.0               4.0      3.0         3.3         3.0
# ..                   ...               ...      ...         ...         ...
# 807                  3.0               3.0      3.0         3.8         3.0
# 808                  5.0               4.0      5.0         5.0         4.5
# 809                  4.0               3.0      3.0         3.5         4.0
# 810                  5.0               5.0      5.0         5.0         5.0
# 811                  NaN               NaN      NaN         NaN         NaN
#
# [812 rows x 9 columns]

# %%
#look at column names
demographics.columns
# Out:
# Index(['items', 'Date', 'No.', 'Learners' ID', 'Full Name', 'Preferred Name',
#        'IC', 'Year', 'Age', 'Gender', 'Nationality', 'Ethnic',
#        'State of residence', 'Email', 'Alternative Email', 'Phone', 'LinkedIn',
#        'Emergency Contact', 'Special Learning Needs',
#        'What is your native language',
#        'What is your primary reason of enrolling?',
#        'Current proficiency of the topics/skills',
#        'How did you hear about this programme?', 'Employment Status',
#        'Current/Last employment date', 'Years of work experience', 'Industry',
#        'Role Title', 'Job position Category', 'Last drawn monthly salary',
#        'Education', 'University Course Name', 'Field of Study', 'Unnamed: 33',
#        'Type of Institution', 'University Name', 'University Name (Others)',
#        'CGPA', 'Graduating Year', 'Household income',
#        'Recipient of Government Aids',
#        'Have you participated in any similar programme? For eg: Penjana, MySTEP, Protege, SL1M, etc (if yes please state which programme you're join)',
#        'I have a working computer or laptop that will be available to me throughout the duration of my course and I have a working internet connection that can handle video streaming.',
#        'What are the 3 factors that are most important to you for learning? (provide a list of 1, 2 and 3)',
#        'What are the 3 factors that are most important for your career? (provide a list of 1, 2 and 3)',
#        'What challenges to learning do you anticipate?',
#        'What type of learning support do you need?',
#        'How many jobs have your applied for in the past 30 days?',
#        'What are the top (most common) 3 roles you've applied for?',
#        'How many interviews have you attended?',
#        'What are your top 3 preferred work locations?',
#        'What is the top 3 factor when you’re considering a job?', 'Segment',
#        'Original Course ID', 'Course ID (1)', 'Status', 'Course ID (2)',
#        'Status.1', 'Course ID (3)', 'Status.2', 'Course ID (4)', 'Status.3',
#        'Course ID (5)', 'Status.4'],
#       dtype='object')

# %%
#check for missing values
df_list = [demographics, outcome, survey]
df_list_names = ["demographics", "outcome", "survey"]

for i in range(len(df_list)):
    df = df_list[i]
    name = df_list_names[i]
    null_counts = df.isnull().sum()
    if null_counts.any():
        print(f"{name} has null values:")
        print(null_counts)
    else:
        print(f"{name} doesn't have null values")
# Out:
# demographics has null values:
# items            812
# Date               0
# No.                0
# Learners' ID       0
# Full Name          0
#                 ...
# Status.2         812
# Course ID (4)    812
# Status.3         812
# Course ID (5)    812
# Status.4         812
# Length: 64, dtype: int64
# outcome has null values:
# Full Name                                     0
# Email                                         0
# Course ID                                     0
# Attendance rate                               0
# Final project score (Fail/ Pass/ scores)      2
# Placement Status                            169
# dtype: int64
# survey has null values:
# Full Name               0
# Email                   0
# Course ID               0
# NPS                    98
# Satisfaction scores    98
# value-time-spent       98
# Content                98
# Instructor             98
# Experience             98
# dtype: int64

# %%
#keeping the missing values in outcome dataframe because the empty values represents that the student did not manage to secure an offer
#keeping the missing values in survey dataframe because the students might have important demograohic data

# %%
#the columns contain null values in the demographics dataframe will be removed as the whole columns are empty
demographics = demographics.drop(['items', 'Status.2','Course ID (4)'], axis=1) # drop the columns

# %%
demographics = demographics.drop(['Preferred Name','Original Course ID', 'Status.1','Status.3','Status.4','Course ID (2)', 'Course ID (3)','Course ID (5)'], axis=1) # drop the columns

# %%
demographics = demographics.drop(['Alternative Email','Emergency Contact', 'Special Learning Needs','What is your native language'], axis=1) # drop the columns

# %%
demographics = demographics.drop(["Have you participated in any similar programme? For eg: Penjana, MySTEP, Protege, SL1M, etc (if yes please state which programme you're join)", "I have a working computer or laptop that will be available to me throughout the duration of my course and I have a working internet connection that can handle video streaming."], axis=1) # drop the columns

# %%
demographics = demographics.drop(['Current/Last employment date'], axis=1) # drop the columns

# %%
demographics = demographics.drop(['Job position Category'], axis=1) # drop the columns

# %%
#check for the remaining missing values in the demographic dataframe 
demographics.isnull().sum()

#keeping all other columns with missing values because other information of the student might be important, and responses are for question 'Please specify if choose others', so it's natural that they are empty
# Out:
# Date                                                                                                    0
# No.                                                                                                     0
# Learners' ID                                                                                            0
# Full Name                                                                                               0
# IC                                                                                                      2
# Year                                                                                                    1
# Age                                                                                                     1
# Gender                                                                                                 12
# Nationality                                                                                             0
# Ethnic                                                                                                  3
# State of residence                                                                                      8
# Email                                                                                                   0
# Phone                                                                                                   4
# LinkedIn                                                                                                4
# What is your primary reason of enrolling?                                                             346
# Current proficiency of the topics/skills                                                              346
# How did you hear about this programme?                                                                 16
# Employment Status                                                                                       3
# Years of work experience                                                                              236
# Industry                                                                                              234
# Role Title                                                                                            234
# Last drawn monthly salary                                                                             233
# Education                                                                                               5
# University Course Name                                                                                 16
# Field of Study                                                                                         17
# Unnamed: 33                                                                                           679
# Type of Institution                                                                                    14
# University Name                                                                                        18
# University Name (Others)                                                                              723
# CGPA                                                                                                   14
# Graduating Year                                                                                         2
# Household income                                                                                       26
# Recipient of Government Aids                                                                           33
# What are the 3 factors that are most important to you for learning? (provide a list of 1, 2 and 3)    346
# What are the 3 factors that are most important for your career? (provide a list of 1, 2 and 3)        346
# What challenges to learning do you anticipate?                                                        356
# What type of learning support do you need?                                                            346
# How many jobs have your applied for in the past 30 days?                                               14
# What are the top (most common) 3 roles you've applied for?                                             14
# How many interviews have you attended?                                                                 25
# What are your top 3 preferred work locations?                                                           4
# What is the top 3 factor when you’re considering a job?                                                 4
# Segment                                                                                                 0
# Course ID (1)                                                                                           0
# Status                                                                                                  0
# dtype: int64

# %%
#rename the unnamed columns 
demographics.rename(columns= {'Unnamed: 33': 'Field of Study (Others)'}, inplace=True)

# %%
demographics.columns
# Out:
# Index(['Date', 'No.', 'Learners' ID', 'Full Name', 'IC', 'Year', 'Age',
#        'Gender', 'Nationality', 'Ethnic', 'State of residence', 'Email',
#        'Phone', 'LinkedIn', 'What is your primary reason of enrolling?',
#        'Current proficiency of the topics/skills',
#        'How did you hear about this programme?', 'Employment Status',
#        'Years of work experience', 'Industry', 'Role Title',
#        'Last drawn monthly salary', 'Education', 'University Course Name',
#        'Field of Study', 'Field of Study (Others)', 'Type of Institution',
#        'University Name', 'University Name (Others)', 'CGPA',
#        'Graduating Year', 'Household income', 'Recipient of Government Aids',
#        'What are the 3 factors that are most important to you for learning? (provide a list of 1, 2 and 3)',
#        'What are the 3 factors that are most important for your career? (provide a list of 1, 2 and 3)',
#        'What challenges to learning do you anticipate?',
#        'What type of learning support do you need?',
#        'How many jobs have your applied for in the past 30 days?',
#        'What are the top (most common) 3 roles you've applied for?',
#        'How many interviews have you attended?',
#        'What are your top 3 preferred work locations?',
#        'What is the top 3 factor when you’re considering a job?', 'Segment',
#        'Course ID (1)', 'Status'],
#       dtype='object')

# %%
survey.columns
# Out:
# Index(['Full Name', 'Email', 'Course ID ', 'NPS', 'Satisfaction scores',
#        'value-time-spent', 'Content', 'Instructor', 'Experience'],
#       dtype='object')

# %%
survey.isnull().value_counts()
# Out:
# Full Name  Email  Course ID   NPS    Satisfaction scores  value-time-spent  Content  Instructor  Experience
# False      False  False       False  False                False             False    False       False         714
#                               True   True                 True              True     True        True           98
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
survey['NPS'].hist(bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('NPS Distribution')
plt.xlabel('NPS')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6))
survey['Satisfaction scores'].hist(bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Satisfaction scores Distribution')
plt.xlabel('Satisfaction score')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6))
survey['value-time-spent'].hist(bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('VTS Distribution')
plt.xlabel('VTS')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#missing values in survey dataframe
#since the scoring by each class is about similar, the missing values will filled up by the mean of the scores (NPS, value time spent, instructor, content, experience) by course id

#columns that need to be filled
columns_tofill = ['NPS','Satisfaction scores','value-time-spent', 'Content', 'Instructor', 'Experience']

#mean scores by course
mean_by_course = survey.groupby('Course ID ')[columns_tofill].mean().round(1)
#fill in the null values 

for column in columns_tofill:
    survey[column] = survey.apply(lambda x: mean_by_course.loc[x['Course ID '], column] if pd.isnull(x[column]) else x[column], axis=1)
    
#check if all null values are filled
survey.isnull().value_counts()
# Out:
# Full Name  Email  Course ID   NPS    Satisfaction scores  value-time-spent  Content  Instructor  Experience
# False      False  False       False  False                False             False    False       False         812
# Name: count, dtype: int64

# %%
#survey_filled['NPS'].mean(), survey_filled['Satisfaction scores'].mean(), survey_filled['value-time-spent'].mean()

##filling the null values with mode has bigger descrapancies in mean values compared to filling null values with mean
## so will proceed with filling null values with mean

# %%
#joining 3 dataframes together 
combined_df= demographics.merge(survey,on='Email').merge(outcome,on='Email')
combined_df
# Out:
#      Date   No. Learners' ID                                   Full Name_x  \
# 0    2023  3138   LN20233138                            Az Khaizuran Azman
# 1    2023  3134   LN20233134                    Deilan Raj Victor Jonathan
# 2    2023  3132   LN20233132                     Emir Aizat Bin Abd Rashid
# 3    2023  3144   LN20233144               Hasanatul Aliah Binti Saifullah
# 4    2023  3137   LN20233137         Mohamad Syahafizin Bin Mohamad Azahar
# ..    ...   ...          ...                                           ...
# 807  2023  3643   LN20233643                                     Shaan Gom
# 808  2023  3644   LN20233644                                Tan Hong Liang
# 809  2023  3645   LN20233645                               Teck Waye Diong
# 810  2023  3646   LN20233646  Ungku Nur Aqilah Hidayah Binti Ungku A Halim
# 811  2023  3647   LN20233647                 Wan Adri Syafi Bin Wan Mahadi
#
#                  IC Year    Age  Gender Nationality            Ethnic  ...  \
# 0    971021-21-6725   27  26-35    Male   Malaysian  Bumiputera Malay  ...
# 1    990709-09-5289   25  18-25    Male   Malaysian            Indian  ...
# 2    950818-18-6401   29  26-35    Male   Malaysian  Bumiputera Malay  ...
# 3    990922-22-5374   25  18-25  Female   Malaysian  Bumiputera Malay  ...
# 4    960903-03-5111   28  26-35    Male   Malaysian  Bumiputera Malay  ...
# ..              ...  ...    ...     ...         ...               ...  ...
# 807  980521-21-5359   26  26-35    Male   Malaysian            Others  ...
# 808  980317-17-6593   26  26-35    Male   Malaysian           Chinese  ...
# 809  971005-05-5285   27  26-35    Male   Malaysian           Chinese  ...
# 810  991021-21-5806   25  18-25  Female   Malaysian  Bumiputera Malay  ...
# 811  991114-14-5077   25  18-25    Male   Malaysian  Bumiputera Malay  ...
#
#     Satisfaction scores value-time-spent  Content Instructor Experience  \
# 0                   4.0              4.0      4.0        5.0        4.0
# 1                   4.0              5.0      4.7        3.8        2.5
# 2                   3.0              3.0      2.7        3.3        3.5
# 3                   4.0              5.0      4.7        4.5        5.0
# 4                   3.0              4.0      3.0        3.3        3.0
# ..                  ...              ...      ...        ...        ...
# 807                 3.0              3.0      3.0        3.8        3.0
# 808                 5.0              4.0      5.0        5.0        4.5
# 809                 4.0              3.0      3.0        3.5        4.0
# 810                 5.0              5.0      5.0        5.0        5.0
# 811                 4.8              4.3      4.6        4.8        4.6
#
#                                         Full Name    Course ID _y  \
# 0                              Az Khaizuran Azman  EC-CCST-23-001
# 1                      Deilan Raj Victor Jonathan  EC-CCST-23-001
# 2                       Emir Aizat Bin Abd Rashid  EC-CCST-23-001
# 3                 Hasanatul Aliah Binti Saifullah  EC-CCST-23-001
# 4           Mohamad Syahafizin Bin Mohamad Azahar  EC-CCST-23-001
# ..                                            ...             ...
# 807                                     Shaan Gom  WC-CITM-23-002
# 808                                Tan Hong Liang  WC-CITM-23-002
# 809                               Teck Waye Diong  WC-CITM-23-002
# 810  Ungku Nur Aqilah Hidayah Binti Ungku A Halim  WC-CITM-23-002
# 811                 Wan Adri Syafi Bin Wan Mahadi  WC-CITM-23-002
#
#     Attendance rate Final project score (Fail/ Pass/ scores)  \
# 0              100%                                Completed
# 1              100%                                Completed
# 2               93%                                Completed
# 3              100%                                Completed
# 4              100%                                Completed
# ..              ...                                      ...
# 807            100%                                Completed
# 808             93%                                Completed
# 809            100%                                Completed
# 810            100%                                Completed
# 811              0%                                      NaN
#
#      Placement Status
# 0                  NaN
# 1            Permanent
# 2            Permanent
# 3            Permanent
# 4                  NaN
# ..                 ...
# 807           Contract
# 808          Permanent
# 809          Permanent
# 810          Permanent
# 811  Withdraw - Others
#
# [812 rows x 58 columns]

# %%
combined_df.columns
# Out:
# Index(['Date', 'No.', 'Learners' ID', 'Full Name_x', 'IC', 'Year', 'Age',
#        'Gender', 'Nationality', 'Ethnic', 'State of residence', 'Email',
#        'Phone', 'LinkedIn', 'What is your primary reason of enrolling?',
#        'Current proficiency of the topics/skills',
#        'How did you hear about this programme?', 'Employment Status',
#        'Years of work experience', 'Industry', 'Role Title',
#        'Last drawn monthly salary', 'Education', 'University Course Name',
#        'Field of Study', 'Field of Study (Others)', 'Type of Institution',
#        'University Name', 'University Name (Others)', 'CGPA',
#        'Graduating Year', 'Household income', 'Recipient of Government Aids',
#        'What are the 3 factors that are most important to you for learning? (provide a list of 1, 2 and 3)',
#        'What are the 3 factors that are most important for your career? (provide a list of 1, 2 and 3)',
#        'What challenges to learning do you anticipate?',
#        'What type of learning support do you need?',
#        'How many jobs have your applied for in the past 30 days?',
#        'What are the top (most common) 3 roles you've applied for?',
#        'How many interviews have you attended?',
#        'What are your top 3 preferred work locations?',
#        'What is the top 3 factor when you’re considering a job?', 'Segment',
#        'Course ID (1)', 'Status', 'Full Name_y', 'Course ID _x', 'NPS',
#        'Satisfaction scores', 'value-time-spent', 'Content', 'Instructor',
#        'Experience', 'Full Name', 'Course ID _y', 'Attendance rate',
#        'Final project score (Fail/ Pass/ scores)', 'Placement Status '],
#       dtype='object')

# %%
#remove the repetitive columns like full name and course ids
combined_df = combined_df.drop(['Full Name_y','Course ID _x','Full Name','Course ID _y'], axis=1) # drop the columns 
combined_df.columns
# Out:
# Index(['Date', 'No.', 'Learners' ID', 'Full Name_x', 'IC', 'Year', 'Age',
#        'Gender', 'Nationality', 'Ethnic', 'State of residence', 'Email',
#        'Phone', 'LinkedIn', 'What is your primary reason of enrolling?',
#        'Current proficiency of the topics/skills',
#        'How did you hear about this programme?', 'Employment Status',
#        'Years of work experience', 'Industry', 'Role Title',
#        'Last drawn monthly salary', 'Education', 'University Course Name',
#        'Field of Study', 'Field of Study (Others)', 'Type of Institution',
#        'University Name', 'University Name (Others)', 'CGPA',
#        'Graduating Year', 'Household income', 'Recipient of Government Aids',
#        'What are the 3 factors that are most important to you for learning? (provide a list of 1, 2 and 3)',
#        'What are the 3 factors that are most important for your career? (provide a list of 1, 2 and 3)',
#        'What challenges to learning do you anticipate?',
#        'What type of learning support do you need?',
#        'How many jobs have your applied for in the past 30 days?',
#        'What are the top (most common) 3 roles you've applied for?',
#        'How many interviews have you attended?',
#        'What are your top 3 preferred work locations?',
#        'What is the top 3 factor when you’re considering a job?', 'Segment',
#        'Course ID (1)', 'Status', 'NPS', 'Satisfaction scores',
#        'value-time-spent', 'Content', 'Instructor', 'Experience',
#        'Attendance rate', 'Final project score (Fail/ Pass/ scores)',
#        'Placement Status '],
#       dtype='object')

# %%
#find null values by rows
combined_df.isnull().sum(axis=1).sort_values(ascending=False)
# Out:
# 701    23
# 249    21
# 145    18
# 414    17
# 63     17
#        ..
# 319     0
# 308     0
# 65      0
# 2       0
# 88      0
# Length: 812, dtype: int64

# %%
combined_df.iloc[701]
#after checking a few lines of the data, will keep all the rows as there are important info in each row.
# Out:
# Date                                                                                                                                               2023
# No.                                                                                                                                                3011
# Learners' ID                                                                                                                                 LN20233011
# Full Name_x                                                                                                                    Yanni A’liah Binti Yazid
# IC                                                                                                                                                   --
# Year                                                                                                                                            #VALUE!
# Age                                                                                                                                             #VALUE!
# Gender                                                                                                                                              NaN
# Nationality                                                                                                                                   Malaysian
# Ethnic                                                                                                                                 Bumiputera Malay
# State of residence                                                                                                                                  NaN
# Email                                                                                                                           yanni.aliah97@gmail.com
# Phone                                                                                                                                      1154239707.0
# LinkedIn                                                                                                                                            NaN
# What is your primary reason of enrolling?                                                                    I want to reskill myself to switch careers
# Current proficiency of the topics/skills                                                              Slightly proficient — I am aware of the topics...
# How did you hear about this programme?                                                                                                              NaN
# Employment Status                                                                                                                                   NaN
# Years of work experience                                                                                                                              1
# Industry                                                                                                                                            NaN
# Role Title                                                                                                                                          NaN
# Last drawn monthly salary                                                                                                                           NaN
# Education                                                                                                                                           NaN
# University Course Name                                                                                                                              NaN
# Field of Study                                                                                                                                      NaN
# Field of Study (Others)                                                                                                                             NaN
# Type of Institution                                                                                                                                 NaN
# University Name                                                                                                                                     NaN
# University Name (Others)                                                                                                                            NaN
# CGPA                                                                                                                                                NaN
# Graduating Year                                                                                                                                    1899
# Household income                                                                                                                                    NaN
# Recipient of Government Aids                                                                                                                        NaN
# What are the 3 factors that are most important to you for learning? (provide a list of 1, 2 and 3)    Assessment, Learning Environment, Teaching Eng...
# What are the 3 factors that are most important for your career? (provide a list of 1, 2 and 3)        Company’s reputation and culture, Job responsi...
# What challenges to learning do you anticipate?                                                                 Learning how to use the tools like figma
# What type of learning support do you need?                                                            Coaching, Consultation with the instructor, Pe...
# How many jobs have your applied for in the past 30 days?                                                                                            NaN
# What are the top (most common) 3 roles you've applied for?                                                                                          NaN
# How many interviews have you attended?                                                                                                              NaN
# What are your top 3 preferred work locations?                                                                                                       NaN
# What is the top 3 factor when you’re considering a job?                                                                                             NaN
# Segment                                                                                                                                     Partnership
# Course ID (1)                                                                                                                            GA-UXBC-23-006
# Status                                                                                                                                        Graduated
# NPS                                                                                                                                                 9.4
# Satisfaction scores                                                                                                                                 4.6
# value-time-spent                                                                                                                                    4.8
# Content                                                                                                                                             4.8
# Instructor                                                                                                                                          4.9
# Experience                                                                                                                                          4.6
# Attendance rate                                                                                                                                    100%
# Final project score (Fail/ Pass/ scores)                                                                                                            80%
# Placement Status                                                                                                                              Permanent
# Name: 701, dtype: object

# %%
#understanding the combined dataframe
combined_df.shape

combined_df.dtypes
# Out:
# Date                                                                                                    int64
# No.                                                                                                     int64
# Learners' ID                                                                                           object
# Full Name_x                                                                                            object
# IC                                                                                                     object
# Year                                                                                                   object
# Age                                                                                                    object
# Gender                                                                                                 object
# Nationality                                                                                            object
# Ethnic                                                                                                 object
# State of residence                                                                                     object
# Email                                                                                                  object
# Phone                                                                                                 float64
# LinkedIn                                                                                               object
# What is your primary reason of enrolling?                                                              object
# Current proficiency of the topics/skills                                                               object
# How did you hear about this programme?                                                                 object
# Employment Status                                                                                      object
# Years of work experience                                                                               object
# Industry                                                                                               object
# Role Title                                                                                             object
# Last drawn monthly salary                                                                              object
# Education                                                                                              object
# University Course Name                                                                                 object
# Field of Study                                                                                         object
# Field of Study (Others)                                                                                object
# Type of Institution                                                                                    object
# University Name                                                                                        object
# University Name (Others)                                                                               object
# CGPA                                                                                                   object
# Graduating Year                                                                                        object
# Household income                                                                                       object
# Recipient of Government Aids                                                                           object
# What are the 3 factors that are most important to you for learning? (provide a list of 1, 2 and 3)     object
# What are the 3 factors that are most important for your career? (provide a list of 1, 2 and 3)         object
# What challenges to learning do you anticipate?                                                         object
# What type of learning support do you need?                                                             object
# How many jobs have your applied for in the past 30 days?                                               object
# What are the top (most common) 3 roles you've applied for?                                             object
# How many interviews have you attended?                                                                 object
# What are your top 3 preferred work locations?                                                          object
# What is the top 3 factor when you’re considering a job?                                                object
# Segment                                                                                                object
# Course ID (1)                                                                                          object
# Status                                                                                                 object
# NPS                                                                                                   float64
# Satisfaction scores                                                                                   float64
# value-time-spent                                                                                      float64
# Content                                                                                               float64
# Instructor                                                                                            float64
# Experience                                                                                            float64
# Attendance rate                                                                                        object
# Final project score (Fail/ Pass/ scores)                                                               object
# Placement Status                                                                                       object
# dtype: object

# %%
combined_df['Phone'].isnull().value_counts()
# Out:
# Phone
# False    808
# True       4
# Name: count, dtype: int64

# %%
#phone number should not be a float, so will convert it to int 
#there are some missing info in the column, so will fill the missing info with 0
combined_df['Phone'] = combined_df['Phone'].fillna(0)
combined_df['Phone'] = pd.to_numeric(combined_df['Phone'], errors='coerce')

combined_df['Phone'] = combined_df['Phone'].astype(int)
combined_df.dtypes
# Out:
# Date                                                                                                    int64
# No.                                                                                                     int64
# Learners' ID                                                                                           object
# Full Name_x                                                                                            object
# IC                                                                                                     object
# Year                                                                                                   object
# Age                                                                                                    object
# Gender                                                                                                 object
# Nationality                                                                                            object
# Ethnic                                                                                                 object
# State of residence                                                                                     object
# Email                                                                                                  object
# Phone                                                                                                   int64
# LinkedIn                                                                                               object
# What is your primary reason of enrolling?                                                              object
# Current proficiency of the topics/skills                                                               object
# How did you hear about this programme?                                                                 object
# Employment Status                                                                                      object
# Years of work experience                                                                               object
# Industry                                                                                               object
# Role Title                                                                                             object
# Last drawn monthly salary                                                                              object
# Education                                                                                              object
# University Course Name                                                                                 object
# Field of Study                                                                                         object
# Field of Study (Others)                                                                                object
# Type of Institution                                                                                    object
# University Name                                                                                        object
# University Name (Others)                                                                               object
# CGPA                                                                                                   object
# Graduating Year                                                                                        object
# Household income                                                                                       object
# Recipient of Government Aids                                                                           object
# What are the 3 factors that are most important to you for learning? (provide a list of 1, 2 and 3)     object
# What are the 3 factors that are most important for your career? (provide a list of 1, 2 and 3)         object
# What challenges to learning do you anticipate?                                                         object
# What type of learning support do you need?                                                             object
# How many jobs have your applied for in the past 30 days?                                               object
# What are the top (most common) 3 roles you've applied for?                                             object
# How many interviews have you attended?                                                                 object
# What are your top 3 preferred work locations?                                                          object
# What is the top 3 factor when you’re considering a job?                                                object
# Segment                                                                                                object
# Course ID (1)                                                                                          object
# Status                                                                                                 object
# NPS                                                                                                   float64
# Satisfaction scores                                                                                   float64
# value-time-spent                                                                                      float64
# Content                                                                                               float64
# Instructor                                                                                            float64
# Experience                                                                                            float64
# Attendance rate                                                                                        object
# Final project score (Fail/ Pass/ scores)                                                               object
# Placement Status                                                                                       object
# dtype: object

# %%
combined_df['Attendance rate'],combined_df['Final project score (Fail/ Pass/ scores)']
# Out:
# (0      100%
#  1      100%
#  2       93%
#  3      100%
#  4      100%
#         ...
#  807    100%
#  808     93%
#  809    100%
#  810    100%
#  811      0%
#  Name: Attendance rate, Length: 812, dtype: object,
#  0      Completed
#  1      Completed
#  2      Completed
#  3      Completed
#  4      Completed
#           ...
#  807    Completed
#  808    Completed
#  809    Completed
#  810    Completed
#  811          NaN
#  Name: Final project score (Fail/ Pass/ scores), Length: 812, dtype: object)

# %%
#convert attendance rate from obj to int
combined_df['Attendance rate'] = combined_df['Attendance rate'].astype(str)
combined_df['Attendance rate'] = combined_df['Attendance rate'].str.rstrip('%').astype(float)
combined_df['Attendance rate']
# Out:
# 0      100.0
# 1      100.0
# 2       93.0
# 3      100.0
# 4      100.0
#        ...
# 807    100.0
# 808     93.0
# 809    100.0
# 810    100.0
# 811      0.0
# Name: Attendance rate, Length: 812, dtype: float64

# %%
combined_df.to_csv('combined_data.csv', index=False)

# %% [markdown]
# # Summary of demographics

# %%
#where are the students from?
combined_df['State of residence'].value_counts(normalize=True)


#About half of the studetns are from Selangor and Kuala Lumpur (which is the major city in Malaysia)
# Out:
# State of residence
# Selangor           0.335821
# Kuala Lumpur       0.149254
# Johor              0.067164
# Perak              0.065920
# Negeri Sembilan    0.049751
# Kelantan           0.048507
# Kedah              0.046020
# Sabah              0.046020
# Pahang             0.042289
# Pulau Pinang       0.039801
# Terengganu         0.038557
# Sarawak            0.036070
# Melaka             0.019900
# Perlis             0.006219
# W.P Labuan         0.003731
# W.P Putrajaya      0.003731
# Putrajaya          0.001244
# Name: proportion, dtype: float64

# %%
combined_df['Employment Status'].value_counts()

#about half of the unemployed are fresh grauduate
# Out:
# Employment Status
# Unemployed              688
# Part-Time Employment     43
# Freelancing              41
# Self-Employed            19
# Retrenched                7
# Intern                    5
# Working Professional      4
# Student                   2
# Name: count, dtype: int64

# %%
working_professionals =combined_df[combined_df['Employment Status'] == 'Working Professional']
working_professionals[['Industry', 'Role Title','Years of work experience','Education','What is your primary reason of enrolling?']]
# Out:
#                        Industry                 Role Title  \
# 115     Marketing & Advertising            Pricing Analyst
# 236  Engineering & Construction       Executive Management
# 410     Consumer Goods & Retail              sales advisor
# 750  Engineering & Construction  Assistant Quality Manager
#
#     Years of work experience Education  \
# 115                      NaN   Diploma
# 236                        1    Degree
# 410                        3    Degree
# 750                        3       NaN
#
#              What is your primary reason of enrolling?
# 115         I want to reskill myself to switch careers
# 236  I want to upskill myself for more job opportun...
# 410  I want to upskill myself for more job opportun...
# 750         I want to reskill myself to switch careers

# %%
combined_df['Graduating Year'].value_counts()

#about half of the umemployed students graduated in the same year, so they will be considered as fresh graduate. 
#there were some invalid responses as well, like 1899 and 1900, they probably chose the first options of the drop down menu
# Out:
# Graduating Year
# 2023       302
# 2022       164
# 2021        94
# 2020        71
# 2019        50
# 2017        36
# 2018        27
# 2016        20
# #VALUE!     19
# 1899        14
# 2015         8
# 2014         3
# 2012         1
# 1900         1
# Name: count, dtype: int64

# %%
#what are their primary reason of enrolling?
combined_df['What is your primary reason of enrolling?'].value_counts(normalize=True)

#about 60% of the students wanted to upskill to have more job opportunities, about 20% of them wanted to pivot career
# Out:
# What is your primary reason of enrolling?
# I want to upskill myself for more job opportunities    0.620172
# I want to reskill myself to switch careers             0.223176
# I want to learn a new skill                            0.115880
# I want to prepare for an upcoming project/position     0.021459
# #REF!                                                  0.010730
# I want to start my own business                        0.006438
# Others                                                 0.002146
# Name: proportion, dtype: float64

# %%
#let's see number of students by course
combined_df['Course ID (1)'].value_counts().sort_index()

#group similar course

combined_df['Grouped_Course'] = combined_df['Course ID (1)'].str.split('-').str[1]

combined_df['Grouped_Course'].value_counts()


#data analytics course has the most number of students, followed by digital marketing and user experience
# Out:
# Grouped_Course
# DABC    298
# DMBC    142
# UXBC    105
# CCST     79
# PPBC     68
# DSBC     45
# PMBC     41
# CITM     34
# Name: count, dtype: int64

# %%
course_proportion= combined_df['Grouped_Course'].value_counts(normalize=True)

plt.figure(figsize=(6, 6))
plt.pie(course_proportion.values, labels=course_proportion.index, autopct='%.1f%%')
plt.title('Proportion of Students by Course')

plt.show()

# %%
#overall background of the learners
combined_df['Field of Study'].value_counts()
# Out:
# Field of Study
# Engineering, Manufacturing, Construction          179
# Business Administration and Law                   173
# Natural Sciences, Mathematics and Statistics      137
# Arts & Humanities                                  88
# Information, Communication, and Technology         87
# Health & Welfare                                   46
# Education                                          25
# Social Sciences, Journalism and Information        21
# Services                                           17
# Agriculture Forestry, Fisheries And Veterinary     14
# Others                                              8
# Name: count, dtype: int64

# %%
#backgroud(tertiary education) of the learners by course
pivot_table = combined_df.groupby(['Grouped_Course', 'Field of Study']).size().unstack(1).fillna(0).astype(int)
pivot_table
# Out:
# Field of Study  Agriculture Forestry, Fisheries And Veterinary  \
# Grouped_Course
# CCST                                                         1
# CITM                                                         1
# DABC                                                         6
# DMBC                                                         3
# DSBC                                                         2
# PMBC                                                         0
# PPBC                                                         0
# UXBC                                                         1
#
# Field of Study  Arts & Humanities  Business Administration and Law  Education  \
# Grouped_Course
# CCST                            6                               11          2
# CITM                            0                                0          0
# DABC                           15                               83          7
# DMBC                           34                               41         12
# DSBC                            0                                2          0
# PMBC                            7                               14          1
# PPBC                            5                                9          0
# UXBC                           21                               13          3
#
# Field of Study  Engineering, Manufacturing, Construction  Health & Welfare  \
# Grouped_Course
# CCST                                                  17                 7
# CITM                                                  24                 0
# DABC                                                  63                18
# DMBC                                                   7                 9
# DSBC                                                  18                 3
# PMBC                                                   7                 2
# PPBC                                                  26                 4
# UXBC                                                  17                 3
#
# Field of Study  Information, Communication, and Technology  \
# Grouped_Course
# CCST                                                    15
# CITM                                                     9
# DABC                                                    17
# DMBC                                                     6
# DSBC                                                     5
# PMBC                                                     1
# PPBC                                                    11
# UXBC                                                    23
#
# Field of Study  Natural Sciences, Mathematics and Statistics  Others  \
# Grouped_Course
# CCST                                                      15       0
# CITM                                                       0       0
# DABC                                                      66       4
# DMBC                                                      14       2
# DSBC                                                      13       0
# PMBC                                                       6       0
# PPBC                                                       9       1
# UXBC                                                      14       1
#
# Field of Study  Services  Social Sciences, Journalism and Information
# Grouped_Course
# CCST                   2                                            2
# CITM                   0                                            0
# DABC                   4                                            8
# DMBC                   8                                            4
# DSBC                   0                                            2
# PMBC                   2                                            1
# PPBC                   1                                            1
# UXBC                   0                                            3

# %%
combined_df['Current proficiency of the topics/skills'].value_counts()
# Out:
# Current proficiency of the topics/skills
# Slightly proficient — I am aware of the topics/skills in theory but have limited application ability    216
# Not at all proficient                                                                                   144
# Quite proficient — I can apply the topics/skills with guidance.                                          89
# Very proficient — I can apply the topics/skills independently with confidence                            12
# #REF!                                                                                                     5
# Name: count, dtype: int64

# %%
pivot_table2 = combined_df.groupby(['Grouped_Course', 'Current proficiency of the topics/skills']).size().unstack(0).fillna(0).astype(int)
pivot_table2
# Out:
# Grouped_Course                                      CCST  CITM  DABC  DMBC  \
# Current proficiency of the topics/skills
# #REF!                                                  0     0     2     1
# Not at all proficient                                 24     7    56    22
# Quite proficient — I can apply the topics/skill...     9     4    27    18
# Slightly proficient — I am aware of the topics/...    15    11    79    44
# Very proficient — I can apply the topics/skills...     3     0     1     4
#
# Grouped_Course                                      DSBC  PMBC  PPBC  UXBC
# Current proficiency of the topics/skills
# #REF!                                                  0     0     2     0
# Not at all proficient                                  3     7    13    12
# Quite proficient — I can apply the topics/skill...     4     5     5    17
# Slightly proficient — I am aware of the topics/...    10     6    18    33
# Very proficient — I can apply the topics/skills...     0     1     3     0

# %% [markdown]
# # Learners Performance

# %%
#overall completion status
combined_df['Status'].value_counts()
# Out:
# Status
# Graduated     791
# Drop Out       18
# Incomplete      3
# Name: count, dtype: int64

# %%
#breakdown of completion status by course
status_by_course= combined_df.groupby(['Grouped_Course', 'Status']).size()
status_by_course
# Out:
# Grouped_Course  Status
# CCST            Drop Out        2
#                 Graduated      77
# CITM            Drop Out        2
#                 Graduated      32
# DABC            Drop Out        3
#                 Graduated     292
#                 Incomplete      3
# DMBC            Drop Out        7
#                 Graduated     135
# DSBC            Drop Out        4
#                 Graduated      41
# PMBC            Graduated      41
# PPBC            Graduated      68
# UXBC            Graduated     105
# dtype: int64

# %%
completion_rate = ((status_by_course / status_by_course.groupby('Grouped_Course').sum())* 100).round(2) 
completion_rate
# Out:
# Grouped_Course  Status
# CCST            Drop Out        2.53
#                 Graduated      97.47
# CITM            Drop Out        5.88
#                 Graduated      94.12
# DABC            Drop Out        1.01
#                 Graduated      97.99
#                 Incomplete      1.01
# DMBC            Drop Out        4.93
#                 Graduated      95.07
# DSBC            Drop Out        8.89
#                 Graduated      91.11
# PMBC            Graduated     100.00
# PPBC            Graduated     100.00
# UXBC            Graduated     100.00
# dtype: float64

# %%
combined_df['Final project score (Fail/ Pass/ scores)'].unique()
# Out:
# array(['Completed', '72%', '0%', '83%', '78%', '67%', '94%', '89%',
#        '100%', '92%', '86%', '99%', '81%', '97%', '96%', '75%', '68%',
#        '69%', '74%', '77%', '70%', '55%', '73%', '66%', '64%', '82%',
#        '76%', '61%', '59%', '80%', '60%', '57%', '63%', '65%', '58%',
#        '91%', '98%', '84%', '93%', '95%', '85%', '87%', '88%', '90%',
#        '71%', '79%', nan], dtype=object)

# %%
#find out the top scorer for each course
#CCST and CITM are not included as the rubric for completion is either completed or failed

courses_with_scores = ['DABC', 'DMBC', 'PPBC', 'PMBC', 'UXBC', 'DSBC']
top_performers_df = pd.DataFrame(columns=['Grouped_Course', 'Full Name_x', 'Final project score (Fail/ Pass/ scores)', 'Attendance rate', 'Placement Status '])

for course in courses_with_scores:
    course_df = combined_df[combined_df['Grouped_Course'] == course]
   
    # Find the maximum score for the current course
    max_score = course_df['Final project score (Fail/ Pass/ scores)'].max()
    
    # Find the row(s) with the maximum score for the current course
    max_score_rows = course_df[course_df['Final project score (Fail/ Pass/ scores)'] == max_score]

    top_performers_df = pd.concat([top_performers_df, max_score_rows])

# %%
top_performers_df

#there are 31 learners in total can be considered as top learners.
# Out:
#     Grouped_Course                                        Full Name_x  \
# 159           DABC                                         Ho Jia Hui
# 165           DABC                         Noor Shafiqah Binti Hashim
# 384           DMBC                             Mellisa Pearl Nemesius
# 394           DMBC                      Nur Diyanah Binti Yusri Anuar
# 402           DMBC                         Nurul Aimi Binti Noor Zali
# 403           DMBC                          NURUL ALIAH BINTI ARASHID
# 411           DMBC     Tengku Amirul Shahril Bin Tengku Shamsubahrian
# 442           DMBC  Nur Shaqinatulhanina Eillin Chung Bt Norazman ...
# 443           DMBC                         Nur Syafiqah Mohamad Hanif
# 456           DMBC                          Syafiqa Binti Showkat Ali
# 468           DMBC              Muhammad Norsyakir Ikhwan Bin Muhamad
# 470           DMBC                  Nik Fatin Amirah Binti Mohd Nasir
# 472           DMBC                          Nor Khairena Binti Khalid
# 474           DMBC                Nur Farhana Adibah Binti Jamaluddin
# 486           DMBC                Siti Noor Syaheera Binti Zaine Noor
# 489           DMBC                     Sumiyyah Binti Hasurol Abudiah
# 492           DMBC                 Yasintha Kusuma Astuty Binti Azimi
# 612           PPBC                                Dominic Goh Jun Wai
# 622           PPBC                   Muhammad Akmal Bin Ahmad Suhaimi
# 632           PPBC                           Norsyazfyera Binti Rosli
# 636           PPBC                          Piravin Raj Barthasarathy
# 649           PPBC                           Harris Danial Bin Hasnan
# 573           PMBC                                      Jiun Li Phang
# 579           PMBC                         Mohamad Akmal Bin Abdullah
# 582           PMBC                      Mohd Ikhsan Bin Mohammad Noor
# 583           PMBC                       Muhammad Afif Bin Mohd Nazim
# 602           PMBC                                      Wai Siang Yun
# 737           UXBC                   Nurul Syamira Binti Abdul Rahman
# 529           DSBC                              Hazman Naim Bin Ahsan
# 534           DSBC                             MAISARAH BINTI IBRAHIM
# 538           DSBC                 MUHAMAD WAFIUDDIN BIN MD KAMARUDIN
#
#     Final project score (Fail/ Pass/ scores)  Attendance rate  \
# 159                                      99%            100.0
# 165                                      99%            100.0
# 384                                      99%             93.0
# 394                                      99%            100.0
# 402                                      99%            100.0
# 403                                      99%             93.0
# 411                                      99%            100.0
# 442                                      99%            100.0
# 443                                      99%            100.0
# 456                                      99%             93.0
# 468                                      99%            100.0
# 470                                      99%            100.0
# 472                                      99%            100.0
# 474                                      99%            100.0
# 486                                      99%            100.0
# 489                                      99%            100.0
# 492                                      99%            100.0
# 612                                      97%            100.0
# 622                                      97%             93.0
# 632                                      97%             93.0
# 636                                      97%            100.0
# 649                                      97%            100.0
# 573                                      93%            100.0
# 579                                      93%            100.0
# 582                                      93%            100.0
# 583                                      93%            100.0
# 602                                      93%            100.0
# 737                                      95%            100.0
# 529                                      99%            100.0
# 534                                      99%            100.0
# 538                                      99%             90.0
#
#     Placement Status     Date     No. Learners' ID              IC     Year  \
# 159         Permanent  2023.0  3147.0   LN20233147  970601-01-5092       27
# 165         Permanent  2023.0  3163.0   LN20233163  930401-01-6196       31
# 384         Permanent  2023.0  3090.0   LN20233090  000326-26-0484       24
# 394               NaN  2023.0  3091.0   LN20233091  000124-24-1138       24
# 402         Permanent  2023.0  3092.0   LN20233092              --  #VALUE!
# 403         Permanent  2023.0  3101.0   LN20233101  001102-02-0450       24
# 411         Permanent  2023.0  3107.0   LN20233107  970430-30-5065       27
# 442          Contract  2023.0  3430.0   LN20233430  990406-06-5732       25
# 443         Permanent  2023.0  3444.0   LN20233444  981204-04-6696       26
# 456         Permanent  2023.0  3450.0   LN20233450  940105-05-5388       30
# 468         Permanent  2023.0  3727.0   LN20233727  000322-22-0373       24
# 470         Permanent  2023.0  3728.0   LN20233728  000716-16-0408       24
# 472         Permanent  2023.0  3730.0   LN20233730  981106-06-6408       26
# 474         Permanent  2023.0  3732.0   LN20233732  020511-11-0382       22
# 486         Permanent  2023.0  3744.0   LN20233744  950618-18-5528       29
# 489          Contract  2023.0  3747.0   LN20233747  980324-24-5190       26
# 492         Permanent  2023.0  3750.0   LN20233750  960102-02-6156       28
# 612         Permanent  2023.0  3240.0   LN20233240  001122-22-0373       24
# 622         Permanent  2023.0  3250.0   LN20233250  020909-09-0121       22
# 632               NaN  2023.0  3236.0   LN20233236  991227-27-5140       25
# 636          Contract  2023.0  3247.0   LN20233247  950511-11-6763       29
# 649          Contract  2023.0  3781.0   LN20233781  971226-26-5253       27
# 573               NaN  2023.0  3200.0   LN20233200  001125-25-1507       24
# 579         Permanent  2023.0  3201.0   LN20233201  020322-22-0647       22
# 582         Permanent  2023.0  3211.0   LN20233211  991210-10-6403       25
# 583               NaN  2023.0  3202.0   LN20233202  971026-26-5575       27
# 602         Permanent  2023.0  3203.0   LN20233203  950601-01-5862       29
# 737         Permanent  2023.0  3363.0   LN20233363  990313-13-5928       25
# 529               NaN  2023.0  3490.0   LN20233490  001010-10-0329       24
# 534         Permanent  2023.0  3505.0   LN20233505  940511-11-5900       30
# 538         Permanent  2023.0  3518.0   LN20233518  990311-11-7383       25
#
#      ... What is the top 3 factor when you’re considering a job?      Segment  \
# 159  ...  Salary\nCareer growth\nCompany’s reputation an...       Partnership
# 165  ...                    Salary\nCareer growth\nLocation       Partnership
# 384  ...           Salary\nLearning opportunities\nLocation       Partnership
# 394  ...  Salary\nCareer growth\nCompany’s reputation an...       Partnership
# 402  ...  Career growth\nLearning opportunities\nCompany...       Partnership
# 403  ...  Career growth\nLearning opportunities\nCompany...       Partnership
# 411  ...  Salary\nCareer growth\nCompany’s reputation an...       Partnership
# 442  ...    Career growth\nLearning opportunities\nLocation       Partnership
# 443  ...             Job responsibilities\nSalary\nLocation       Partnership
# 456  ...                    Salary\nCareer growth\nLocation       Partnership
# 468  ...    Career growth\nLearning opportunities\nLocation       Partnership
# 470  ...             Job responsibilities\nSalary\nLocation       Partnership
# 472  ...                Title\nJob responsibilities\nSalary       Partnership
# 474  ...  Job responsibilities\nCareer growth\nLearning ...       Partnership
# 486  ...  Career growth\nLearning opportunities\nCompany...       Partnership
# 489  ...  Career growth\nLearning opportunities\nCompany...       Partnership
# 492  ...        Job responsibilities\nSalary\nCareer growth       Partnership
# 612  ...  Salary\nCompany’s reputation and culture\nLoca...       Partnership
# 622  ...      Salary\nCareer growth\nLearning opportunities       Partnership
# 632  ...  Job responsibilities\nCareer growth\nCompany’s...       Partnership
# 636  ...  Career growth\nLearning opportunities\nCompany...       Partnership
# 649  ...  Career growth\nLearning opportunities\nCompany...       Partnership
# 573  ...  Job responsibilities\nLearning opportunities\n...       Partnership
# 579  ...  Career growth\nLearning opportunities\nCompany...       Partnership
# 582  ...  Job responsibilities\nCareer growth\nCompany’s...       Partnership
# 583  ...  Career growth\nLearning opportunities\nCompany...       Partnership
# 602  ...      Salary\nCareer growth\nLearning opportunities       Partnership
# 737  ...        Job responsibilities\nSalary\nCareer growth       Partnership
# 529  ...  Career growth\nLearning opportunities\nCompany...       Partnership
# 534  ...      Salary\nCareer growth\nLearning opportunities       Partnership
# 538  ...  Salary\nLearning opportunities\nCompany’s repu...       Partnership
#
#       Course ID (1)     Status   NPS Satisfaction scores  value-time-spent  \
# 159  GA-DABC-23-015  Graduated  10.0                 5.0               4.0
# 165  GA-DABC-23-015  Graduated  10.0                 5.0               5.0
# 384  GA-DMBC-23-004  Graduated   9.0                 4.0               4.0
# 394  GA-DMBC-23-004  Graduated   9.0                 5.0               5.0
# 402  GA-DMBC-23-004  Graduated   9.6                 4.8               4.7
# 403  GA-DMBC-23-004  Graduated  10.0                 5.0               5.0
# 411  GA-DMBC-23-004  Graduated  10.0                 5.0               5.0
# 442  GA-DMBC-23-005  Graduated   9.5                 4.8               4.6
# 443  GA-DMBC-23-005  Graduated   9.0                 5.0               5.0
# 456  GA-DMBC-23-005  Graduated  10.0                 4.0               4.0
# 468  GA-DMBC-23-006  Graduated   9.5                 4.9               4.8
# 470  GA-DMBC-23-006  Graduated  10.0                 5.0               5.0
# 472  GA-DMBC-23-006  Graduated  10.0                 5.0               5.0
# 474  GA-DMBC-23-006  Graduated  10.0                 5.0               5.0
# 486  GA-DMBC-23-006  Graduated  10.0                 5.0               5.0
# 489  GA-DMBC-23-006  Graduated  10.0                 5.0               5.0
# 492  GA-DMBC-23-006  Graduated   9.0                 5.0               4.0
# 612  GA-PPBC-23-003  Graduated   7.0                 4.0               5.0
# 622  GA-PPBC-23-003  Graduated  10.0                 1.0               4.0
# 632  GA-PPBC-23-003  Graduated  10.0                 5.0               5.0
# 636  GA-PPBC-23-003  Graduated   9.0                 4.0               5.0
# 649  GA-PPBC-23-004  Graduated   9.0                 5.0               4.0
# 573  GA-PMBC-23-004  Graduated   9.5                 4.7               4.6
# 579  GA-PMBC-23-004  Graduated  10.0                 5.0               5.0
# 582  GA-PMBC-23-004  Graduated  10.0                 5.0               1.0
# 583  GA-PMBC-23-004  Graduated   9.5                 4.7               4.6
# 602  GA-PMBC-23-004  Graduated   9.0                 5.0               5.0
# 737  GA-UXBC-23-007  Graduated  10.0                 5.0               5.0
# 529  GA-DSBC-23-003  Graduated  10.0                 5.0               6.0
# 534  GA-DSBC-23-003  Graduated   9.0                 4.0               4.0
# 538  GA-DSBC-23-003  Graduated  10.0                 5.0               5.0
#
#     Content Instructor Experience
# 159     4.3        5.0        4.0
# 165     4.3        5.0        5.0
# 384     4.0        4.0        4.0
# 394     4.0        5.0        5.0
# 402     4.7        4.8        4.7
# 403     5.0        5.0        5.0
# 411     5.0        5.0        5.0
# 442     4.7        4.8        4.6
# 443     5.0        4.0        4.0
# 456     4.0        5.0        5.0
# 468     4.9        4.9        4.8
# 470     4.7        5.0        5.0
# 472     5.0        5.0        5.0
# 474     5.0        5.0        5.0
# 486     5.0        5.0        5.0
# 489     5.0        5.0        5.0
# 492     4.3        4.9        4.0
# 612     4.0        4.0        3.5
# 622     5.0        5.0        5.0
# 632     5.0        5.0        5.0
# 636     4.0        4.0        4.0
# 649     5.0        5.0        5.0
# 573     4.7        4.9        4.7
# 579     5.0        5.0        5.0
# 582     4.3        5.0        4.0
# 583     4.7        4.9        4.7
# 602     4.0        5.0        5.0
# 737     5.0        5.0        5.0
# 529     5.0        5.0        5.0
# 534     4.0        4.8        4.0
# 538     5.0        5.0        5.0
#
# [31 rows x 55 columns]

# %%
top_performers_df['Grouped_Course'].value_counts(), top_performers_df['Placement Status '].value_counts()

#there are a lot of learners score 'the highest score' in DMBC 
## most of the top performers secured a job offer
# Out:
# (Grouped_Course
#  DMBC    15
#  PPBC     5
#  PMBC     5
#  DSBC     3
#  DABC     2
#  UXBC     1
#  Name: count, dtype: int64,
#  Placement Status
#  Permanent    22
#  Contract      4
#  Name: count, dtype: int64)

# %% [markdown]
# # Learners Satisfation

# %%
#let's see student's scores (from survey) based on course

combined_df['Satisfaction scores'].value_counts(), combined_df['value-time-spent'].value_counts(), combined_df['Content'].value_counts(),combined_df['Instructor'].value_counts(),combined_df['Experience'].value_counts()

#columns to count
columns_tocount = ['Satisfaction scores','value-time-spent', 'Content', 'Instructor', 'Experience']

#mean scores by course
mean_by_course = combined_df.groupby('Grouped_Course')[columns_tocount].mean().round(1)
mean_by_course = pd.DataFrame(mean_by_course)
mean_by_course

##DMBC and UXBC learners rated highest satisfaction score, wheras CSCT learners has the lowest satisfaction scores
# Out:
#                 Satisfaction scores  value-time-spent  Content  Instructor  \
# Grouped_Course
# CCST                            4.4               4.5      4.4         4.4
# CITM                            4.7               4.3      4.4         4.8
# DABC                            4.7               4.7      4.7         4.8
# DMBC                            4.8               4.7      4.7         4.8
# DSBC                            4.6               4.7      4.6         4.8
# PMBC                            4.7               4.6      4.7         4.9
# PPBC                            4.5               4.6      4.6         4.8
# UXBC                            4.8               4.7      4.7         4.8
#
#                 Experience
# Grouped_Course
# CCST                   4.5
# CITM                   4.5
# DABC                   4.7
# DMBC                   4.7
# DSBC                   4.6
# PMBC                   4.7
# PPBC                   4.7
# UXBC                   4.6

# %%
ax= mean_by_course.plot(kind='bar', stacked=True, figsize=(10, 4))

for container in ax.containers:
    ax.bar_label(container, label_type='center', color='white', fontweight='bold')
    
plt.title('Satisfaction Scores by Course')
plt.xlabel('Course')
plt.ylabel('Scores')
plt.xticks(rotation = 0)
plt.legend(title='Scores')
ax.legend(bbox_to_anchor=(1.0, 1.05))

plt.show()

# %%
#calculate NPS for each course 

# categorize responses into promoters, passives, and detractors
promoters = combined_df[combined_df['NPS'] >= 9].groupby('Grouped_Course').size()
passives = combined_df[(combined_df['NPS'] >= 7) & (combined_df['NPS'] < 9)].groupby('Grouped_Course').size()
detractors = combined_df[combined_df['NPS'] <= 6].groupby('Grouped_Course').size()

#fill in detractor count as 0
all_courses = combined_df['Grouped_Course'].unique()
detractors = detractors.reindex(all_courses, fill_value=0)



# calculate the percentage of promoters, passives, and detractors 
total_responses = promoters + passives + detractors
promoter_percentage = promoters / total_responses * 100
detractor_percentage = detractors / total_responses * 100


# calculate the NPS for each course
nps_by_course = (promoter_percentage - detractor_percentage).round(1)


print(nps_by_course)

##PMBC has the highest NPS score; CCST has the lowest NPS score
# Out:
# Grouped_Course
# CCST    63.3
# CITM    76.5
# DABC    86.2
# DMBC    92.3
# DSBC    75.6
# PMBC    92.7
# PPBC    80.9
# UXBC    85.7
# dtype: float64

# %%
ax2 = nps_by_course.plot(kind='bar', figsize=(10, 4))

for container in ax2.containers:
    ax2.bar_label(container, label_type='edge', fontweight='bold')

plt.title('NPS by Course')
plt.xlabel('Course')
plt.ylabel('Scores')
plt.xticks(rotation=0)

ax2.set_ylim([0, 100])

plt.show()

##looks like the courses do not invlove data analysis score higher in NPS
