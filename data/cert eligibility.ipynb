# %%
import pandas as pd

# Define the eligibility criteria
def passing_score(score):
    if isinstance(score, str):  # Check if the value is 'completed'
        if score.lower().strip( ) == 'completed':
            return True  
        else:
            try:
                score = float(score.rstrip('%'))
                return score >= 55
            except ValueError:
                return False  
    elif isinstance(score, (int, float)):
        return score >= 55
    else:
        return False

def check_eligibility(df, output_file):
    completed_finalproject = df['Final project score (Fail/ Pass/ scores)'].apply(passing_score)
    achieve_attendance = df['Attendance rate'] >= 80
    placement_status = df['Placement Status '].isin(['Permanent', 'Contract', 'Self-employment'])
   
    # Combine the criteria to determine eligibility
    df['Cert Eligibility'] = completed_finalproject & achieve_attendance & placement_status
    
    df.to_csv(output_file, index=False)
    print("Certificate eligibility check completed.")
    
    return df

if __name__ == "__main__":
    # to enter input and output file paths
    input_file = input("Enter the location of input CSV file: ")
    output_file = input("Enter the location of output CSV file: ")
    
    # Read input CSV to define df
    df = pd.read_csv(input_file)
    
    # Run certificate eligibility check
    modified_df = check_eligibility(df, output_file)
# Out:
# Enter the location of input CSV file: combined_data.csv
# Enter the location of output CSV file: output.csv
# Certificate eligibility check completed.

# %%
modified_df
# Out:
#      Date   No. Learners' ID                                   Full Name_x  \
# 0    2023  3138   LN20233138                            Az Khaizuran Azman
# 1    2023  3134   LN20233134                    Deilan Raj Victor Jonathan
# 2    2023  3132   LN20233132                     Emir Aizat Bin Abd Rashid
# 3    2023  3144   LN20233144               Hasanatul Aliah Binti Saifullah
# 4    2023  3137   LN20233137         Mohamad Syahafizin Bin Mohamad Azahar
# ..    ...   ...          ...                                           ...
# 807  2023  3643   LN20233643                                     Shaan Gom
# 808  2023  3644   LN20233644                                Tan Hong Liang
# 809  2023  3645   LN20233645                               Teck Waye Diong
# 810  2023  3646   LN20233646  Ungku Nur Aqilah Hidayah Binti Ungku A Halim
# 811  2023  3647   LN20233647                 Wan Adri Syafi Bin Wan Mahadi
#
#                  IC Year    Age  Gender Nationality            Ethnic  ...  \
# 0    971021-21-6725   27  26-35    Male   Malaysian  Bumiputera Malay  ...
# 1    990709-09-5289   25  18-25    Male   Malaysian            Indian  ...
# 2    950818-18-6401   29  26-35    Male   Malaysian  Bumiputera Malay  ...
# 3    990922-22-5374   25  18-25  Female   Malaysian  Bumiputera Malay  ...
# 4    960903-03-5111   28  26-35    Male   Malaysian  Bumiputera Malay  ...
# ..              ...  ...    ...     ...         ...               ...  ...
# 807  980521-21-5359   26  26-35    Male   Malaysian            Others  ...
# 808  980317-17-6593   26  26-35    Male   Malaysian           Chinese  ...
# 809  971005-05-5285   27  26-35    Male   Malaysian           Chinese  ...
# 810  991021-21-5806   25  18-25  Female   Malaysian  Bumiputera Malay  ...
# 811  991114-14-5077   25  18-25    Male   Malaysian  Bumiputera Malay  ...
#
#         Status   NPS  Satisfaction scores value-time-spent Content Instructor  \
# 0    Graduated   8.0                  4.0              4.0     4.0        5.0
# 1    Graduated   8.0                  4.0              5.0     4.7        3.8
# 2    Graduated   5.0                  3.0              3.0     2.7        3.3
# 3    Graduated   8.0                  4.0              5.0     4.7        4.5
# 4    Graduated   7.0                  3.0              4.0     3.0        3.3
# ..         ...   ...                  ...              ...     ...        ...
# 807  Graduated   6.0                  3.0              3.0     3.0        3.8
# 808  Graduated  10.0                  5.0              4.0     5.0        5.0
# 809  Graduated   8.0                  4.0              3.0     3.0        3.5
# 810  Graduated  10.0                  5.0              5.0     5.0        5.0
# 811   Drop Out   9.2                  4.8              4.3     4.6        4.8
#
#     Experience Attendance rate Final project score (Fail/ Pass/ scores)  \
# 0          4.0           100.0                                Completed
# 1          2.5           100.0                                Completed
# 2          3.5            93.0                                Completed
# 3          5.0           100.0                                Completed
# 4          3.0           100.0                                Completed
# ..         ...             ...                                      ...
# 807        3.0           100.0                                Completed
# 808        4.5            93.0                                Completed
# 809        4.0           100.0                                Completed
# 810        5.0           100.0                                Completed
# 811        4.6             0.0                                      NaN
#
#      Placement Status
# 0                  NaN
# 1            Permanent
# 2            Permanent
# 3            Permanent
# 4                  NaN
# ..                 ...
# 807           Contract
# 808          Permanent
# 809          Permanent
# 810          Permanent
# 811  Withdraw - Others
#
# [812 rows x 54 columns]
